# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,BatchNormalization,Flatten,Conv2D,MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train_dir="D:\\AI Project\\skin\\data\\train"
test_dir="D:\\AI Project\\skin\\data\\test"

datagn=ImageDataGenerator(rescale=1/255,validation_split=0.2,zoom_range=.2,shear_range=.2,rotation_range=.3)
test_datagn=ImageDataGenerator(rescale=1/255)


train_set=datagn.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=4,
    class_mode="categorical",
    subset="training"
    )

valid_set=datagn.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=4,
    class_mode="categorical",
    subset="validation"
)

test_set=test_datagn.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="categorical"
)
# Out:
# Found 7684 images belonging to 2 classes.
# Found 1921 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
from keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # Uses float16 for calculations where possible
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3050 Laptop GPU, compute capability 8.6

# %%
train_set.class_indices
# Out:
# {'benign': 0, 'malignant': 1}

# %%
labels=['benign','malignant']
print(labels)
# Out:
# ['benign', 'malignant']

# %%
plt.figure(figsize=(10, 5))

for i in range(15):  
    plt.subplot(3, 5, i+1) 
    image, label = train_set.next()  
    plt.imshow(image[0])  
    plt.axis("off")  
    plt.title(f"Class: {labels[np.argmax(label)]}") 

plt.tight_layout()  
plt.show()

# %%
model=Sequential()

model.add(Conv2D(32,(3,3),activation="relu",padding="same",input_shape=(224,224,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())


model.add(Conv2D(100,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())

model.add(Conv2D(28,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())

model.add(Conv2D(16,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(500,activation="relu"))
model.add(Dropout(.5))

model.add(Dense(200,activation="relu"))
model.add(Dropout(.2))

model.add(Dense(50,activation="relu"))
model.add(Dropout(.3))

model.add(Dense(2,activation="softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 224, 224, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 112, 112, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 110, 110, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 55, 55, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 55, 55, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 53, 53, 100)       57700
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 100)      0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 26, 26, 100)      400
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 28)        25228
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 28)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 12, 12, 28)       112
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 16)        4048
#
#  max_pooling2d_8 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 5, 5, 16)         64
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_4 (Dense)             (None, 500)               200500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_5 (Dense)             (None, 200)               100200
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_6 (Dense)             (None, 50)                10050
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_7 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 418,052
# Trainable params: 417,636
# Non-trainable params: 416
# _________________________________________________________________

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
histroy=model.fit(train_set,epochs=30,validation_data=valid_set,batch_size=4)
# Out:
# Epoch 1/30
# 1921/1921 [==============================] - 59s 30ms/step - loss: 0.4661 - accuracy: 0.7876 - val_loss: 0.4419 - val_accuracy: 0.7361
# Epoch 2/30
# 1921/1921 [==============================] - 57s 30ms/step - loss: 0.3894 - accuracy: 0.8277 - val_loss: 0.3440 - val_accuracy: 0.8235
# Epoch 3/30
# 1921/1921 [==============================] - 62s 32ms/step - loss: 0.3647 - accuracy: 0.8457 - val_loss: 0.3411 - val_accuracy: 0.8438
# Epoch 4/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.3560 - accuracy: 0.8459 - val_loss: 0.3756 - val_accuracy: 0.8313
# Epoch 5/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.3450 - accuracy: 0.8522 - val_loss: 0.4001 - val_accuracy: 0.8194
# Epoch 6/30
# 1921/1921 [==============================] - 62s 32ms/step - loss: 0.3288 - accuracy: 0.8572 - val_loss: 0.3085 - val_accuracy: 0.8839
# Epoch 7/30
# 1921/1921 [==============================] - 69s 36ms/step - loss: 0.3182 - accuracy: 0.8632 - val_loss: 0.3625 - val_accuracy: 0.8178
# Epoch 8/30
# 1921/1921 [==============================] - 62s 32ms/step - loss: 0.3183 - accuracy: 0.8644 - val_loss: 0.3124 - val_accuracy: 0.8824
# Epoch 9/30
# 1921/1921 [==============================] - 59s 30ms/step - loss: 0.3109 - accuracy: 0.8670 - val_loss: 0.3124 - val_accuracy: 0.8563
# Epoch 10/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.3015 - accuracy: 0.8757 - val_loss: 0.3799 - val_accuracy: 0.8339
# Epoch 11/30
# 1921/1921 [==============================] - 58s 30ms/step - loss: 0.3015 - accuracy: 0.8748 - val_loss: 0.2903 - val_accuracy: 0.8683
# Epoch 12/30
# 1921/1921 [==============================] - 56s 29ms/step - loss: 0.2931 - accuracy: 0.8775 - val_loss: 0.2999 - val_accuracy: 0.8574
# Epoch 13/30
# 1921/1921 [==============================] - 58s 30ms/step - loss: 0.2919 - accuracy: 0.8813 - val_loss: 0.2828 - val_accuracy: 0.8641
# Epoch 14/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2844 - accuracy: 0.8883 - val_loss: 0.3009 - val_accuracy: 0.8808
# Epoch 15/30
# 1921/1921 [==============================] - 57s 30ms/step - loss: 0.2825 - accuracy: 0.8843 - val_loss: 0.3835 - val_accuracy: 0.7808
# Epoch 16/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2853 - accuracy: 0.8864 - val_loss: 0.3141 - val_accuracy: 0.8589
# Epoch 17/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2647 - accuracy: 0.8930 - val_loss: 0.2759 - val_accuracy: 0.8803
# Epoch 18/30
# 1921/1921 [==============================] - 60s 31ms/step - loss: 0.2654 - accuracy: 0.8891 - val_loss: 0.2756 - val_accuracy: 0.9001
# Epoch 19/30
# 1921/1921 [==============================] - 60s 31ms/step - loss: 0.2610 - accuracy: 0.8943 - val_loss: 0.2735 - val_accuracy: 0.8860
# Epoch 20/30
# 1921/1921 [==============================] - 59s 30ms/step - loss: 0.2644 - accuracy: 0.8943 - val_loss: 0.2629 - val_accuracy: 0.8954
# Epoch 21/30
# 1921/1921 [==============================] - 60s 31ms/step - loss: 0.2592 - accuracy: 0.8976 - val_loss: 0.3939 - val_accuracy: 0.8131
# Epoch 22/30
# 1921/1921 [==============================] - 68s 36ms/step - loss: 0.2525 - accuracy: 0.9001 - val_loss: 0.3141 - val_accuracy: 0.8917
# Epoch 23/30
# 1921/1921 [==============================] - 59s 30ms/step - loss: 0.2587 - accuracy: 0.8982 - val_loss: 0.2640 - val_accuracy: 0.8964
# Epoch 24/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2598 - accuracy: 0.8971 - val_loss: 0.2646 - val_accuracy: 0.8974
# Epoch 25/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2520 - accuracy: 0.8977 - val_loss: 0.2520 - val_accuracy: 0.9011
# Epoch 26/30
# 1921/1921 [==============================] - 58s 30ms/step - loss: 0.2502 - accuracy: 0.9034 - val_loss: 0.2758 - val_accuracy: 0.9016
# Epoch 27/30
# 1921/1921 [==============================] - 59s 30ms/step - loss: 0.2445 - accuracy: 0.9010 - val_loss: 0.2649 - val_accuracy: 0.8881
# Epoch 28/30
# 1921/1921 [==============================] - 58s 30ms/step - loss: 0.2408 - accuracy: 0.9029 - val_loss: 0.2373 - val_accuracy: 0.8964
# Epoch 29/30
# 1921/1921 [==============================] - 58s 30ms/step - loss: 0.2336 - accuracy: 0.9049 - val_loss: 0.2596 - val_accuracy: 0.8974
# Epoch 30/30
# 1921/1921 [==============================] - 59s 31ms/step - loss: 0.2372 - accuracy: 0.9068 - val_loss: 0.2527 - val_accuracy: 0.9058

# %%
test_loss,test_acc=model.evaluate(test_set)
print(test_acc)
# Out:
# 32/32 [==============================] - 1s 31ms/step - loss: 0.2370 - accuracy: 0.8960
# 0.8960000276565552

# %%
pd.DataFrame(histroy.history).plot()
plt.show()

# %%
model.save("skin_3.h5")
